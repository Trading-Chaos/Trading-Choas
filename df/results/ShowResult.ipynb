# %%
import pandas as pd

# %%
df = pd.read_csv("Results.csv")
df
# Out:
#           task_type model_name model_family target_name target_variant  \
# 0    classification    XGBoost          xgb         ttp         3class
# 1    classification    XGBoost          xgb         ttp         3class
# 2    classification    XGBoost          xgb         ttp         3class
# 3    classification    XGBoost          xgb         ttp         3class
# 4    classification    XGBoost          xgb         ttp         3class
# ..              ...        ...          ...         ...            ...
# 285  classification    XGBoost          xgb      hybrid  GoodTrade+TTP
# 286  classification    XGBoost          xgb         ttp         3class
# 287  classification    XGBoost          xgb      hybrid  GoodTrade+TTP
# 288  classification    XGBoost          xgb         ttp         3class
# 289  classification    XGBoost          xgb      hybrid  GoodTrade+TTP
#
#                  horizons                                 confusion_matrix  \
# ...
