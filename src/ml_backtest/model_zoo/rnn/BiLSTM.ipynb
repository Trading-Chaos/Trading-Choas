# %% [markdown]
# # **BilSTM**

# %% [markdown]
# BiLSTM — это двунаправленная LSTM: она смотрит на последовательность и слева-направо, и справа-налево одновременно.
#
# По сути это “LSTM с двумя мозгами”:
#
# первый читает ряд как обычно: от прошлого к будущему;
#
# второй — наоборот: от будущего к прошлому;
#
# их состояния склеиваются и подаются дальше

# %% [markdown]
# hₜ = [ h⃗ₜ ; h⃖ₜ ]

# %% [markdown]
# h⃗ₜ — LSTM вперёд по времени
#
# h⃖ₜ — LSTM назад
#
# [ ; ] — конкатенация

# %%
import sys, os
sys.path.append(os.path.abspath("../.."))

# %%
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
from preprocessing.preprocess import prep, append_results
from preprocessing.target import ttp_target
from metrics.Metrics import merged_metrics
from preprocessing.ForTorch import set_seed, DEVICE, SeqDataset, torch_predict, train_torch_classifier, train_tabnet_ttp
name = "AFKS"
df: pd.DataFrame = pd.read_csv(f"/Users/side/Desktop/Trading Chaos AI/df/clean_df/{name}.csv")

# %% [markdown]
# ...

# %%
import numpy as np

def analyze_class_balance(
    y: np.ndarray,
    n_classes: int = 3,
    min_frac_warn: float = 0.05,
    verbose: bool = True,
):
    """
    Анализ распределения классов + рекомендации.
    """
    counts = np.bincount(y, minlength=n_classes)
    total = counts.sum()
    frac = counts / max(total, 1)

    if verbose:
        print("Class balance:")
        for i in range(n_classes):
            print(f"  class {i}: {counts[i]} ({frac[i]*100:.2f}%)")

        if np.any(frac < min_frac_warn):
            print("⚠️  Strong class imbalance detected")

    return {
        "counts": counts,
        "fractions": frac,
        "total": total,
    }

# %%
class BiLSTMCls(nn.Module):
    def init(self, n_features, hidden=64, n_classes=3, dropout=0.2):
        super().init()
        self.lstm = nn.LSTM(
            input_size=n_features,
            hidden_size=hidden,
            batch_first=True,
            bidirectional=True
        )
        self.drop = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden*2, n_classes)

    def forward(self, x):   # x: (B, L, F)
        out, _ = self.lstm(x)
        h = out[:, -1, :]          # last step
        h = self.drop(h)
        return self.fc(h)

def train_bilstm_ttp(df, train_size, test_size, step, seq_len=64):
    set_seed(42)
    splitter = prep(
        df=df,
        target_fn=ttp_target,
        target_name="ttp",
        target_col="TTP_class",
        horizons=[12,24,48],
        train_size=train_size,
        test_size=test_size,
        step=step,
        target_kwargs={"n_classes":3},
        scale_cols=[
            "Open","High","Low","Close",
            "Alligator_Jaw","Alligator_Teeth","Alligator_Lips",
            "AO","AddOn_Anchor_Level","AddOn_Size_Pct"
        ]
    )
    for X_train, X_test, y_train, y_test, scaler in splitter:
        # seq датасеты
        tr_ds = SeqDataset(X_train, y_train, seq_len=seq_len)
        te_ds = SeqDataset(X_test,  y_test,  seq_len=seq_len)

        tr_loader = DataLoader(tr_ds, batch_size=256, shuffle=True, drop_last=False)
        te_loader = DataLoader(te_ds, batch_size=512, shuffle=False, drop_last=False)

        model = ChaosBiLSTM(input_size=X_train.shape[1], hidden=64, n_classes=3, dropout=0.2)

        y_pred = train_torch_classifier(
            model=model,
            train_loader=tr_loader,
            test_loader=te_loader,
            epochs=15,
            lr=1e-3
        )

        # y_test тоже надо “сдвинуть” под seq_len
        y_test_seq = y_test[seq_len-1:]
        metrics = merged_metrics(y_test_seq, y_pred)

        append_results({
            "task_type":"classification",
            "model_name":"BiLSTM",
            "model_family":"rnn",
            "model_params":{"hidden":64,"dropout":0.2,"seq_len":seq_len},
            "target_name":"ttp",
            "target_variant":"3class",
            "horizons":"12_24_48",
            **metrics
        })

# %%
import torch
import torch.nn as nn

class ChaosBiLSTM(nn.Module):
    def __init__(self, input_size: int, hidden: int = 64, n_classes: int = 3, dropout: float = 0.2):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden,
            batch_first=True,
            bidirectional=True
        )
        self.drop = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden * 2, n_classes)

    def forward(self, x):  # (B,L,F)
        out, _ = self.lstm(x)
        h = out[:, -1, :]
        h = self.drop(h)
        return self.fc(h)

# %%
train_bilstm_ttp(df, 1000, 200, 100, seq_len=64)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 train_bilstm_ttp(df, 1000, 200, 100, seq_len=64)
#
# Cell In[21], line 37, in train_bilstm_ttp(df, train_size, test_size, step, seq_len)
#      20 set_seed(42)
#      21 splitter = prep(
#      22     df=df,
#      23     target_fn=ttp_target,
#    (...)     35     ]
#      36 )
# ---> 37 print("y_train dist:", np.bincount(y_train.values))
#      38 print("y_test  dist:", np.bincount(y_test.values))
#      39 for X_train, X_test, y_train, y_test, scaler in splitter:
#      40     # seq датасеты
#
# UnboundLocalError: cannot access local variable 'y_train' where it is not associated with a value

# %%
import numpy as np

def analyze_class_balance(
    y: np.ndarray,
    n_classes: int = 3,
    min_frac_warn: float = 0.05,
    verbose: bool = True,
):
    """
    Анализ распределения классов + рекомендации.
    """
    counts = np.bincount(y, minlength=n_classes)
    total = counts.sum()
    frac = counts / max(total, 1)

    if verbose:
        print("Class balance:")
        for i in range(n_classes):
            print(f"  class {i}: {counts[i]} ({frac[i]*100:.2f}%)")

        if np.any(frac < min_frac_warn):
            print("⚠️  Strong class imbalance detected")

    return {
        "counts": counts,
        "fractions": frac,
        "total": total,
    }

# %%
import numpy as np

def show_class_balance(
    y,
    n_classes: int = 3,
    title: str | None = None,
):
    """
    Печатает распределение классов.
    Ничего не меняет, только диагностирует.
    """
    y = np.asarray(y)
    counts = np.bincount(y, minlength=n_classes)
    total = counts.sum()

    if title:
        print(f"\n=== {title} ===")

    print("Class balance:")
    for i in range(n_classes):
        pct = 100.0 * counts[i] / total if total > 0 else 0.0
        print(f"  class {i}: {counts[i]:6d} ({pct:6.2f}%)")
