# %% [markdown]
# # **Tabtransformer**

# %% [markdown]
# трансформер для табличных данных (особенно с категориями).
# Суть: делает контекстные эмбеддинги категориальных признаков, учитывая их взаимосвязи.

# %% [markdown]
# E = Transformer(Emb(x₁), … , Emb(xₙ))

# %% [markdown]
# Emb(xᵢ) — эмбеддинг признака; E — контекстные представления.

# %%
import sys, os
sys.path.append(os.path.abspath("../.."))

# %%
import numpy as np
import pandas as pd
from preprocessing.preprocess import prep, append_results, eval_thresholds
from preprocessing.target import ttp_target, hybrid_target
from metrics.Metrics import merged_metrics
name = "AFKS"
df: pd.DataFrame = pd.read_csv(f"/Users/side/Desktop/Trading Chaos AI/df/clean_df/{name}.csv")
