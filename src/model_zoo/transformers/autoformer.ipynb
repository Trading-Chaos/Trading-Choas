# %% [markdown]
# # **Autoformer**

# %% [markdown]
# Это ещё один «специализированный трансформер» для временных рядов, близкий по духу к FEDformer, но с другим ключевым механизмом: auto-correlation вместо классического self-attention + явная декомпозиция тренд+сезонность на каждом слое.

# %% [markdown]
# R(τ) = ∑ₜ xₜ · xₜ₋τ

# %% [markdown]
# τ — лаг; R(τ) — автокорреляция.

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Dense, Dropout, LayerNormalization,
    Add, Lambda, AveragePooling1D, Conv1D
)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
from df.DataForModel import df, build_target
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from data_preprocessing.DataForModel import df, build_target
#
# ModuleNotFoundError: No module named 'data_preprocessing'
